# %%
import numpy as np
import pandas as pd

# %%
#index_col is none to ignore the last col which has the random errors
data = pd.read_csv("https://raw.githubusercontent.com/hadragon26/Take_home_finatier/main/finantier_data_technical_test_dataset.csv",index_col=False)
# Out:
# C:\Users\Hari Shiman\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:311: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   return func(*args, **kwargs)

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     4808-GHDJN  Female            NaN     NaN        NaN     NaN
# 1     7590-VHVEG  Female            0.0     Yes         No     1.0
# 2     5575-GNVDE    Male            0.0      No         No    34.0
# 3     3668-QPYBK    Male            0.0      No         No     2.0
# 4     7795-CFOCW    Male            0.0      No         No    45.0
# ...          ...     ...            ...     ...        ...     ...
# 7043  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7044  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7045  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7046  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7047  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0             NaN               NaN             NaN            NaN  ...
# ...

# %%
#find the number of na in each column
data.isna().sum()
# Out:
# customerID          4
# gender              4
# SeniorCitizen       5
# Partner             5
# Dependents          5
# tenure              5
# PhoneService        5
# MultipleLines       5
# InternetService     5
# OnlineSecurity      5
# OnlineBackup        5
# DeviceProtection    5
# TechSupport         5
# StreamingTV         5
# StreamingMovies     5
# Contract            5
# PaperlessBilling    5
# PaymentMethod       5
# MonthlyCharges      5
# TotalCharges        5
# Default             5
# dtype: int64

# %%
data[data["customerID"].isna()]
data[data["Partner"].isna()]


#customerID-GHDJN do not have any details about her except that she is female and her id
# the rest of the na columns has no details at all
#drop all the rows with NA
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   4808-GHDJN  Female            NaN     NaN        NaN     NaN          NaN
# 10         NaN     NaN            NaN     NaN        NaN     NaN          NaN
# 19         NaN     NaN            NaN     NaN        NaN     NaN          NaN
# 28         NaN     NaN            NaN     NaN        NaN     NaN          NaN
# 38         NaN     NaN            NaN     NaN        NaN     NaN          NaN
#
#    MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0            NaN             NaN            NaN  ...              NaN
# 10           NaN             NaN            NaN  ...              NaN
# 19           NaN             NaN            NaN  ...              NaN
# 28           NaN             NaN            NaN  ...              NaN
# 38           NaN             NaN            NaN  ...              NaN
#
#    TechSupport StreamingTV StreamingMovies Contract PaperlessBilling  \
# ...

# %%
#aftter drop na
# drop 5columns

data.dropna()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1     7590-VHVEG  Female            0.0     Yes         No     1.0
# 2     5575-GNVDE    Male            0.0      No         No    34.0
# 3     3668-QPYBK    Male            0.0      No         No     2.0
# 4     7795-CFOCW    Male            0.0      No         No    45.0
# 5     9237-HQITU  Female            0.0      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 7043  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7044  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7045  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7046  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7047  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1              No  No phone service             DSL             No  ...
# ...

# %%
data_clean = data.dropna()
data_clean
data_clean.info()

# all the columns except seniorcitizen , tenure and monthlycharges are non numeric so need to convert
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 1 to 7047
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   float64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   float64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
#do not need id for prediction

data_update = data_clean.drop(["customerID"],axis=1)
data_update
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 1     Female            0.0     Yes         No     1.0           No
# 2       Male            0.0      No         No    34.0          Yes
# 3       Male            0.0      No         No     2.0          Yes
# 4       Male            0.0      No         No    45.0           No
# 5     Female            0.0      No         No     2.0          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7043    Male            0.0     Yes        Yes    24.0          Yes
# 7044  Female            0.0     Yes        Yes    72.0          Yes
# 7045  Female            0.0     Yes        Yes    11.0           No
# 7046    Male            1.0     Yes         No     4.0          Yes
# 7047    Male            0.0      No         No    66.0          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 1     No phone service             DSL             No          Yes
# ...

# %%
#able to factorise the non numeric cloumns , # total charges are not numeric do not need to factorise this just change to numeric 
# need to factorise the rest that is not numeric



for col in data_update:
  print(data_update[col].unique())
# Out:
# ['Female' 'Male']
# [0. 1.]
# ['Yes' 'No']
# ['No' 'Yes']
# [ 1. 34.  2. 45.  8. 22. 10. 28. 62. 13. 16. 58. 49. 25. 69. 52. 71. 21.
#  12. 30. 47. 72. 17. 27.  5. 46. 11. 70. 63. 43. 15. 60. 18. 66.  9.  3.
#  31. 50. 64. 56.  7. 42. 35. 48. 29. 65. 38. 68. 32. 55. 37. 36. 41.  6.
#   4. 33. 67. 23. 57. 61. 14. 20. 53. 40. 59. 24. 44. 19. 54. 51. 26.  0.
#  39.]
# ['No' 'Yes']
# ['No phone service' 'No' 'Yes']
# ['DSL' 'Fiber optic' 'No']
# ['No' 'Yes' 'No internet service']
# ['Yes' 'No' 'No internet service']
# ['No' 'Yes' 'No internet service']
# ['No' 'Yes' 'No internet service']
# ['No' 'Yes' 'No internet service']
# ['No' 'Yes' 'No internet service']
# ['Month-to-month' 'One year' 'Two year']
# ['Yes' 'No']
# ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# ['29.85' '1889.5' '108.15' ... '346.45' '306.6' '6844.5']
# ['No' 'Yes']

# %%
data_update.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Default'],
#       dtype='object')

# %%
data_update[['gender', 'Partner', 'Dependents',
       'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
        'Default']] = data_update[['gender', 'Partner', 'Dependents',
       'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
        'Default']].apply(lambda x: pd.factorize(x)[0])

# %%
data_update[['tenure']] = data_update[['tenure']].apply(lambda x: pd.factorize(x)[0])

# %%
# covert total charges to numeric
data_update["TotalCharges"] = data_update["TotalCharges"].astype(float)
#data_update[["TotalCharges"]] = data_update[["TotalCharges"]].apply(pd.to_numeric,errors='ignore')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\HARISH~1\AppData\Local\Temp/ipykernel_18424/2636021309.py in <module>
#       1 # covert total charges to numeric
# ----> 2 data_update["TotalCharges"] = data_update["TotalCharges"].astype(float)
#       3 #data_update[["TotalCharges"]] = data_update[["TotalCharges"]].apply(pd.to_numeric,errors='ignore')
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ...

# %%
data_update = data_update[data_update["TotalCharges"] != " "]

# %%
data_update["TotalCharges"] = data_update["TotalCharges"].astype(float)
# Out:
# C:\Users\HARISH~1\AppData\Local\Temp/ipykernel_18424/1162314070.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_update["TotalCharges"] = data_update["TotalCharges"].astype(float)

# %%
data_update.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 1 to 7047
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7032 non-null   int64
#  1   SeniorCitizen     7032 non-null   float64
#  2   Partner           7032 non-null   int64
#  3   Dependents        7032 non-null   int64
#  4   tenure            7032 non-null   int64
#  5   PhoneService      7032 non-null   int64
#  6   MultipleLines     7032 non-null   int64
#  7   InternetService   7032 non-null   int64
#  8   OnlineSecurity    7032 non-null   int64
#  9   OnlineBackup      7032 non-null   int64
#  10  DeviceProtection  7032 non-null   int64
#  11  TechSupport       7032 non-null   int64
#  12  StreamingTV       7032 non-null   int64
#  13  StreamingMovies   7032 non-null   int64
#  14  Contract          7032 non-null   int64
#  15  PaperlessBilling  7032 non-null   int64
# ...

# %%
# feature selection 

import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

X = data_update.iloc[:,0:19]  #independent columns
y = data_update.iloc[:,-1]    #target column i.e price range
#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=10)
fit = bestfeatures.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(10,'Score'))
# Out:
#                Specs          Score
# 18      TotalCharges  629630.810349
# 17    MonthlyCharges    3653.074681
# 4             tenure    2143.359991
# 14          Contract    1111.759054
# 8     OnlineSecurity     685.871020
# 11       TechSupport     668.700540
# 16     PaymentMethod     488.182700
# 10  DeviceProtection     433.699657
# 13   StreamingMovies     213.065348
# 12       StreamingTV     211.105842

# %%
import pandas as pd
import numpy as np

X = data_update.iloc[:,0:19]  #independent columns
y = data_update.iloc[:,-1]    #target column i.e price range
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,y)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# [0.03790402 0.02608244 0.03055596 0.024416   0.11609196 0.0057725
#  0.02976299 0.03307771 0.04316399 0.03065988 0.03297542 0.04309008
#  0.02679729 0.02608456 0.09611018 0.02951195 0.06638476 0.13392121
#  0.16763708]

# %%
X = data_update.iloc[:,-1]
X
# Out:
# 1       0
# 2       0
# 3       1
# 4       0
# 5       1
#        ..
# 7043    0
# 7044    0
# 7045    0
# 7046    1
# 7047    0
# Name: Default, Length: 7032, dtype: int64

# %%
# Feature Extraction with RFE
from pandas import read_csv
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
# load data
array = data_update.values
X = array[:,0:19]  #independent columns
y = array[:,19]    #target column i.e price range
# feature extraction
model = LogisticRegression(solver='lbfgs',max_iter=1000)
rfe = RFE(model,n_features_to_select=3)
fit = rfe.fit(X, y)
print("Num Features: %d" % fit.n_features_)
print("Selected Features: %s" % fit.support_)
print("Feature Ranking: %s" % fit.ranking_)

# 7,8,14,15,11
# Out:
# Num Features: 3
# Selected Features: [False False False False False False False  True  True False False False
#  False False  True False False False False]
# Feature Ranking: [13 11  9  4 14  6 16  1  1  5  8  2 10 12  1  3  7 15 17]

# %%
y
# Out:
# array([0., 0., 1., ..., 0., 1., 0.])
